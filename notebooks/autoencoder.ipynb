# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets import load_dataset
from PIL import Image
from io import BytesIO
import time
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

# %%
ds = load_dataset("poloclub/diffusiondb", split='train')
ds
# Out:
# Dataset({
#     features: ['image', 'prompt', 'seed', 'step', 'cfg', 'sampler', 'width', 'height', 'user_name', 'timestamp', 'image_nsfw', 'prompt_nsfw'],
#     num_rows: 1000
# })

# %%
for x in ds:
    display(x['prompt'])
    display(x['image'])
    time.sleep(2)
    clear_output(wait=True)
# Out:
# 'four year old boy with short blonde hair, asleep at christmas. surrounded by gifts. high quality detailed face. beautiful painting by artgerm and greg rutkowski and bouguereau '
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x704>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 4
#       2 display(x['prompt'])
#       3 display(x['image'])
# ----> 4 time.sleep(2)
#       5 clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
ds2 = load_dataset('lesc-unifi/dragon', 'Regular')
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_000.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_001.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_002.tar:   0%|          | 0.00/3.12G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_003.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_004.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_005.tar:   0%|          | 0.00/3.11G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_006.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_007.tar:   0%|          | 0.00/3.12G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_008.tar:   0%|          | 0.00/3.11G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_train_009.tar:   0%|          | 0.00/3.10G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_00.tar:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_01.tar:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_02.tar:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_03.tar:   0%|          | 0.00/1.30G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_04.tar:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_05.tar:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_06.tar:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_07.tar:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_08.tar:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# dragon_test_09.tar:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/55 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
k=8
x=ds[k]
plt.imshow(x['image']);
print(x['prompt']);
# Out:
# a t shirt all over print, portrait of black panther, trippy background, neon glow, tie dye, one piece art style, cartoon, anime, digital art

# %%
jj = list(range(len(ds2['train'])))
import random
random.shuffle(jj)
for ii in jj:
    x = ds2['train'][ii]
    display(x['json']['prompt'])
    display(x['png'])
    time.sleep(2)
    clear_output(wait=True)
# Out:
# "close-up, high quality image of a marine biologist's specimenas collection, underwater scene, clear water visibility with ray and fish in the foreground, vibrant colors showcasing distinctive features such as electric ray's barbels, crampfish's armored body, numbfish's elongated shape, Torpedo fish swimming gracefully at the bottom of a coral reef, Nikon D850 24-70mm f/2.8 lens, macro photography"
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 8
#       6 display(x['json']['prompt'])
#       7 display(x['png'])
# ----> 8 time.sleep(2)
#       9 clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
x.keys()
# Out:
# dict_keys(['json', 'model.txt', 'png', 'prompt.cls', '__key__', '__url__'])

# %%
x['json']
# Out:
# {'model': 'Flash_PixArt',
#  'prompt': 'a cozy artisan bakery filled with aromas of freshly baked bread and pastries, warm lighting, rustic brick walls, traditional wooden furniture, professional food photography, vibrant colors, Nikon D850 170mm lens',
#  'prompt_id': None,
#  'sample_num': 0,
#  'seed': 4837993371}

# %%
o = x['png']

# %%
o.width, o.height
# Out:
# (1024, 1024)
